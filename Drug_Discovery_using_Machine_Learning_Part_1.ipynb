# %%
import pandas as pd
data_frame = pd.read_csv('/content/bioactivity_data_preprocessed.csv')
data_frame
# Out:
#     molecule_chembl_id  ... bioactivity_class
# 0         CHEMBL187579  ...          inactive
# 1         CHEMBL188487  ...          inactive
# 2         CHEMBL185698  ...            active
# 3         CHEMBL426082  ...            active
# 4         CHEMBL187717  ...          inactive
# ..                 ...  ...               ...
# 128      CHEMBL2146517  ...               NaN
# 129       CHEMBL187460  ...               NaN
# 130       CHEMBL363535  ...               NaN
# 131       CHEMBL227075  ...               NaN
# 132        CHEMBL45830  ...               NaN
#
# [133 rows x 4 columns]

# %% [markdown]
# # New section

# %%
data_no_smiles = data_frame.drop(columns='canonical_smiles')
data_no_smiles
# Out:
#     molecule_chembl_id  standard_value bioactivity_class
# 0         CHEMBL187579          7200.0          inactive
# 1         CHEMBL188487          9400.0          inactive
# 2         CHEMBL185698         13500.0            active
# 3         CHEMBL426082         13110.0            active
# 4         CHEMBL187717          2000.0          inactive
# ..                 ...             ...               ...
# 128      CHEMBL2146517         10600.0               NaN
# 129       CHEMBL187460         10100.0               NaN
# 130       CHEMBL363535         11500.0               NaN
# 131       CHEMBL227075         10700.0               NaN
# 132        CHEMBL45830         78900.0               NaN
#
# [133 rows x 3 columns]

# %%
smiles = []

for i in data_frame.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
data_clean_smiles = pd.concat([data_no_smiles,smiles], axis=1)
data_clean_smiles
# Out:
#     molecule_chembl_id  ...                                   canonical_smiles
# 0         CHEMBL187579  ...             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487  ...             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698  ...            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082  ...                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717  ...    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...  ...                                                ...
# 128      CHEMBL2146517  ...  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460  ...        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535  ...             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075  ...      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830  ...             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
# [133 rows x 4 columns]

# %%
pip install rdkit-pypi
# Out:
# ...
#      |████████████████████████████████| 20.6 MB 1.2 MB/s
# ...

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
def lipinski(smiles, verbose=False):

    molcdata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        molcdata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in molcdata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
data_lipinski = lipinski(data_clean_smiles.canonical_smiles)
data_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
data_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
data_frame
# Out:
#     molecule_chembl_id  ... bioactivity_class
# 0         CHEMBL187579  ...          inactive
# 1         CHEMBL188487  ...          inactive
# 2         CHEMBL185698  ...            active
# 3         CHEMBL426082  ...            active
# 4         CHEMBL187717  ...          inactive
# ..                 ...  ...               ...
# 128      CHEMBL2146517  ...               NaN
# 129       CHEMBL187460  ...               NaN
# 130       CHEMBL363535  ...               NaN
# 131       CHEMBL227075  ...               NaN
# 132        CHEMBL45830  ...               NaN
#
# [133 rows x 4 columns]

# %%
data_combined = pd.concat([data_frame,data_lipinski], axis=1)

# %%
data_combined
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL187579  ...           5.0
# 1         CHEMBL188487  ...           2.0
# 2         CHEMBL185698  ...           4.0
# 3         CHEMBL426082  ...           3.0
# 4         CHEMBL187717  ...           5.0
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...           5.0
# 129       CHEMBL187460  ...           3.0
# 130       CHEMBL363535  ...           3.0
# 131       CHEMBL227075  ...           3.0
# 132        CHEMBL45830  ...           2.0
#
# [133 rows x 8 columns]

# %%
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
data_combined.standard_value.describe()
# Out:
# count    1.330000e+02
# mean     8.017926e+12
# std      3.344888e+13
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      3.311311e+14
# Name: standard_value, dtype: float64

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# 1.0

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# -1.0

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %%
data_norm = norm_value(data_combined)
data_norm
# Out:
#     molecule_chembl_id  ... standard_value_norm
# 0         CHEMBL187579  ...              7200.0
# 1         CHEMBL188487  ...              9400.0
# 2         CHEMBL185698  ...             13500.0
# 3         CHEMBL426082  ...             13110.0
# 4         CHEMBL187717  ...              2000.0
# ..                 ...  ...                 ...
# 128      CHEMBL2146517  ...             10600.0
# 129       CHEMBL187460  ...             10100.0
# 130       CHEMBL363535  ...             11500.0
# 131       CHEMBL227075  ...             10700.0
# 132        CHEMBL45830  ...             78900.0
#
# [133 rows x 8 columns]

# %%
data_norm.standard_value_norm.describe()
# Out:
# count    1.330000e+02
# mean     2.110164e+07
# std      4.089714e+07
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      1.000000e+08
# Name: standard_value_norm, dtype: float64

# %%
data_final = pIC50(data_norm)
data_final
# Out:
#     molecule_chembl_id  ...     pIC50
# 0         CHEMBL187579  ...  5.142668
# 1         CHEMBL188487  ...  5.026872
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 4         CHEMBL187717  ...  5.698970
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [133 rows x 8 columns]

# %%
data_final.pIC50.describe()
# Out:
# count    133.000000
# mean       4.060148
# std        1.783762
# min        1.000000
# 25%        3.522879
# 50%        4.628932
# 75%        4.970616
# max        7.301030
# Name: pIC50, dtype: float64

# %%
data_final.to_csv('covid_04_bioactivity_data_3class_pIC50.csv')

# %%
data_2class = data_final[data_final['bioactivity_class'] != 'intermediate']
data_2class
# Out:
#     molecule_chembl_id  ...     pIC50
# 0         CHEMBL187579  ...  5.142668
# 1         CHEMBL188487  ...  5.026872
# 2         CHEMBL185698  ...  4.869666
# 3         CHEMBL426082  ...  4.882397
# 4         CHEMBL187717  ...  5.698970
# ..                 ...  ...       ...
# 128      CHEMBL2146517  ...  4.974694
# 129       CHEMBL187460  ...  4.995679
# 130       CHEMBL363535  ...  4.939302
# 131       CHEMBL227075  ...  4.970616
# 132        CHEMBL45830  ...  4.102923
#
# [133 rows x 8 columns]

# %%
data_2class.to_csv('covid_05_bioactivity_data_2class_pIC50.csv')

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 6))

sns.countplot(x='bioactivity_class', data=data_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('Frequency', fontsize=15, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %%
plt.figure(figsize=(6,6))

sns.scatterplot(x='MW', y='LogP', data=data_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=15, fontweight='bold')
plt.ylabel('LogP', fontsize=15, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %%
plt.figure(figsize=(6, 6))

sns.boxplot(x = 'bioactivity_class', y = 'pIC50', data = data_2class)

plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=15, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %%
def mannwhitney(descriptor, verbose=False):
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  dataframe = data_2class[selection]
  active = dataframe[dataframe['bioactivity_class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  dataframe = data_2class[selection]
  inactive = dataframe[dataframe['bioactivity_class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics  ...  alpha                         Interpretation
# 0      pIC50       588.0  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(6, 6))

sns.boxplot(x = 'bioactivity_class', y = 'MW', data = data_2class)

plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('MW', fontsize=15, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics  ...  alpha                         Interpretation
# 0         MW       591.0  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(6, 6))

sns.boxplot(x = 'bioactivity_class', y = 'LogP', data = data_2class)

plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('LogP', fontsize=15, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics       p  alpha                         Interpretation
# 0       LogP       677.0  0.2059   0.05  Same distribution (fail to reject H0)

# %%
plt.figure(figsize=(6, 6))

sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = data_2class)

plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=15, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics  ...  alpha                         Interpretation
# 0  NumHDonors       599.5  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
plt.figure(figsize=(6, 6))

sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = data_2class)

plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=15, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics  ...  alpha                         Interpretation
# 0  NumHAcceptors       726.0  ...   0.05  Same distribution (fail to reject H0)
#
# [1 rows x 5 columns]

# %%
import pandas as pd

# %%
dataframe3 = pd.read_csv('covid_04_bioactivity_data_3class_pIC50.csv')

# %%
dataframe3
# Out:
#      Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0             0       CHEMBL187579  ...           5.0  5.142668
# 1             1       CHEMBL188487  ...           2.0  5.026872
# 2             2       CHEMBL185698  ...           4.0  4.869666
# 3             3       CHEMBL426082  ...           3.0  4.882397
# 4             4       CHEMBL187717  ...           5.0  5.698970
# ..          ...                ...  ...           ...       ...
# 128         128      CHEMBL2146517  ...           5.0  4.974694
# 129         129       CHEMBL187460  ...           3.0  4.995679
# 130         130       CHEMBL363535  ...           3.0  4.939302
# 131         131       CHEMBL227075  ...           3.0  4.970616
# 132         132        CHEMBL45830  ...           2.0  4.102923
#
# [133 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
dataframe3_selection = dataframe3[selection]
dataframe3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
dataframe3_X = pd.read_csv('descriptors_output.csv')

# %%
dataframe3_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL130098           1  ...             0             0
# 1      CHEMBL130478           1  ...             0             0
# 2      CHEMBL339995           1  ...             0             0
# 3      CHEMBL336538           1  ...             0             0
# 4      CHEMBL341437           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 5098   CHEMBL513063           1  ...             0             0
# 5099  CHEMBL4645659           1  ...             0             0
# 5100  CHEMBL4638958           1  ...             0             0
# 5101  CHEMBL4640608           1  ...             0             0
# 5102  CHEMBL4173961           1  ...             0             0
#
# [5103 rows x 882 columns]

# %%
dataframe3_X = dataframe3_X.drop(columns=['Name'])
dataframe3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 5098           1           1  ...             0             0
# 5099           1           1  ...             0             0
# 5100           1           1  ...             0             0
# 5101           1           1  ...             0             0
# 5102           1           1  ...             0             0
#
# [5103 rows x 881 columns]

# %%
dataframe3_Y = dataframe3['pIC50']
dataframe3_Y
# Out:
# 0      5.142668
# 1      5.026872
# 2      4.869666
# 3      4.882397
# 4      5.698970
#          ...
# 128    4.974694
# 129    4.995679
# 130    4.939302
# 131    4.970616
# 132    4.102923
# Name: pIC50, Length: 133, dtype: float64

# %%
dataset3 = pd.concat([dataframe3_X,dataframe3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           0  ...             0             0  5.142668
# 1              1           1           0  ...             0             0  5.026872
# 2              1           1           1  ...             0             0  4.869666
# 3              1           1           1  ...             0             0  4.882397
# 4              1           1           1  ...             0             0  5.698970
# ...          ...         ...         ...  ...           ...           ...       ...
# 5098           1           1           1  ...             0             0       NaN
# 5099           1           1           1  ...             0             0       NaN
# 5100           1           1           1  ...             0             0       NaN
# 5101           1           1           1  ...             0             0       NaN
# ...

# %%
dataset3.to_csv('covid_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
dataframe = pd.read_csv('covid_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = dataframe.drop('pIC50', axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 5098           1           1  ...             0             0
# 5099           1           1  ...             0             0
# 5100           1           1  ...             0             0
# 5101           1           1  ...             0             0
# 5102           1           1  ...             0             0
#
# [5103 rows x 881 columns]

# %%
Y = dataframe.pIC50
Y
# Out:
# 0       5.142668
# 1       5.026872
# 2       4.869666
# 3       4.882397
# 4       5.698970
#           ...
# 5098         NaN
# 5099         NaN
# 5100         NaN
# 5101         NaN
# 5102         NaN
# Name: pIC50, Length: 5103, dtype: float64

# %%
X.shape
# Out:
# (5103, 881)

# %%
Y.shape
# Out:
# (5103,)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (5103, 140)

# %%
# !pip install sklearn

# %%
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((4082, 140), (4082,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((1021, 140), (1021,))

# %%
import numpy as np
x = np.nan_to_num(X_train)
y = np.nan_to_num(Y_train)

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(x, y)
r2 = model.score(x, y)
r2
# Out:
# 0.7835179639386616

# %%
Y_pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>

# %%
# !pip install lazypredict
# Out:
# ...
#      |████████████████████████████████| 72 kB 788 kB/s
# ...
#      |████████████████████████████████| 14.5 MB 29.3 MB/s
# ...
#      |████████████████████████████████| 127.6 MB 24 kB/s
# ...
#      |████████████████████████████████| 248 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 302 kB 66.3 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 74.1 MB/s
# ...
#      |████████████████████████████████| 25.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 64.8 MB/s
# ...
#      |████████████████████████████████| 269 kB 88.0 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 67.2 MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44635 sha256=a376a447b4ada8c0183fcf0b1fb35d8f5c9edd478686484054d0cb400ed682ef
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall scikit - learn - y
# !pip install scikit - learn == 0.24 .1
# Out:
# ERROR: Invalid requirement: '-'
# ERROR: Invalid requirement: '-'

# %%
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
dataframe = pd.read_csv('covid_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = dataframe.drop('pIC50', axis=1)
Y = dataframe.pIC50

# %%
# Examine X dimension
X.shape
# Out:
# (5103, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (5103, 140)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# ...
# 100%|██████████| 42/42 [00:00<00:00, 76062.51it/s]
