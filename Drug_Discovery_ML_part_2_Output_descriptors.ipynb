# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
#   inflating: __MACOSX/PaDEL-Descriptor/._config
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
#   inflating: PaDEL-Descriptor/Descriptors.xls
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
#    creating: PaDEL-Descriptor/lib/
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
#   inflating: PaDEL-Descriptor/descriptors.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %%
import pandas as pd

# %%
df3 = pd.read_csv('/content/covid_04_bioactivity_data_3class_pIC50 (1) (1).csv')

# %%
df3
# Out:
#      Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0             0       CHEMBL187579  ...           5.0  5.142668
# 1             1       CHEMBL188487  ...           2.0  5.026872
# 2             2       CHEMBL185698  ...           4.0  4.869666
# 3             3       CHEMBL426082  ...           3.0  4.882397
# 4             4       CHEMBL187717  ...           5.0  5.698970
# ..          ...                ...  ...           ...       ...
# 128         128      CHEMBL2146517  ...           5.0  4.974694
# 129         129       CHEMBL187460  ...           3.0  4.995679
# 130         130       CHEMBL363535  ...           3.0  4.939302
# 131         131       CHEMBL227075  ...           3.0  4.970616
# 132         132        CHEMBL45830  ...           2.0  4.102923
#
# [133 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21	CHEMBL187579
# O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21	CHEMBL188487
# O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21	CHEMBL185698
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21	CHEMBL426082
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]	CHEMBL187717

# %%
! cat molecule.smi | wc -l
# Out:
# 133

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL187579 in molecule.smi (1/133).
# Processing CHEMBL188487 in molecule.smi (2/133).
# Processing CHEMBL185698 in molecule.smi (3/133). Average speed: 1.64 s/mol.
# Processing CHEMBL426082 in molecule.smi (4/133). Average speed: 0.86 s/mol.
# Processing CHEMBL187717 in molecule.smi (5/133). Average speed: 0.70 s/mol.
# Processing CHEMBL187598 in molecule.smi (7/133). Average speed: 0.53 s/mol.
# Processing CHEMBL365134 in molecule.smi (6/133). Average speed: 0.58 s/mol.
# Processing CHEMBL190743 in molecule.smi (8/133). Average speed: 0.48 s/mol.
# Processing CHEMBL365469 in molecule.smi (9/133). Average speed: 0.45 s/mol.
# Processing CHEMBL188983 in molecule.smi (10/133). Average speed: 0.42 s/mol.
# Processing CHEMBL191575 in molecule.smi (11/133). Average speed: 0.40 s/mol.
# Processing CHEMBL370923 in molecule.smi (12/133). Average speed: 0.38 s/mol.
# Processing CHEMBL194398 in molecule.smi (13/133). Average speed: 0.36 s/mol.
# Processing CHEMBL196635 in molecule.smi (14/133). Average speed: 0.35 s/mol.
# Processing CHEMBL209287 in molecule.smi (15/133). Average speed: 0.34 s/mol.
# Processing CHEMBL358279 in molecule.smi (16/133). Average speed: 0.32 s/mol.
# Processing CHEMBL348660 in molecule.smi (17/133). Average speed: 0.31 s/mol.
# Processing CHEMBL379727 in molecule.smi (18/133). Average speed: 0.31 s/mol.
# Processing CHEMBL210525 in molecule.smi (19/133). Average speed: 0.30 s/mol.
# Processing CHEMBL148483 in molecule.smi (20/133). Average speed: 0.29 s/mol.
# Processing CHEMBL383725 in molecule.smi (21/133). Average speed: 0.28 s/mol.
# Processing CHEMBL118596 in molecule.smi (22/133). Average speed: 0.27 s/mol.
# Processing CHEMBL208732 in molecule.smi (24/133). Average speed: 0.27 s/mol.
# Processing CHEMBL208732 in molecule.smi (23/133). Average speed: 0.27 s/mol.
# Processing CHEMBL210146 in molecule.smi (25/133). Average speed: 0.26 s/mol.
# Processing CHEMBL210146 in molecule.smi (26/133). Average speed: 0.26 s/mol.
# Processing CHEMBL207458 in molecule.smi (27/133). Average speed: 0.26 s/mol.
# Processing CHEMBL207458 in molecule.smi (28/133). Average speed: 0.26 s/mol.
# Processing CHEMBL207484 in molecule.smi (29/133). Average speed: 0.25 s/mol.
# Processing CHEMBL207484 in molecule.smi (30/133). Average speed: 0.25 s/mol.
# Processing CHEMBL207207 in molecule.smi (31/133). Average speed: 0.24 s/mol.
# Processing CHEMBL207207 in molecule.smi (32/133). Average speed: 0.24 s/mol.
# Processing CHEMBL210487 in molecule.smi (33/133). Average speed: 0.24 s/mol.
# Processing CHEMBL380470 in molecule.smi (35/133). Average speed: 0.24 s/mol.
# Processing CHEMBL210487 in molecule.smi (34/133). Average speed: 0.24 s/mol.
# Processing CHEMBL380470 in molecule.smi (36/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210612 in molecule.smi (37/133). Average speed: 0.24 s/mol.
# Processing CHEMBL209667 in molecule.smi (39/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210612 in molecule.smi (38/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210097 in molecule.smi (41/133). Average speed: 0.23 s/mol.
# Processing CHEMBL209667 in molecule.smi (40/133). Average speed: 0.23 s/mol.
# Processing CHEMBL378674 in molecule.smi (43/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210097 in molecule.smi (42/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210216 in molecule.smi (45/133). Average speed: 0.23 s/mol.
# Processing CHEMBL378674 in molecule.smi (44/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210216 in molecule.smi (46/133). Average speed: 0.23 s/mol.
# Processing CHEMBL210195 in molecule.smi (47/133). Average speed: 0.22 s/mol.
# Processing CHEMBL210195 in molecule.smi (48/133). Average speed: 0.22 s/mol.
# Processing CHEMBL210437 in molecule.smi (50/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210437 in molecule.smi (49/133). Average speed: 0.22 s/mol.
# Processing CHEMBL378677 in molecule.smi (51/133). Average speed: 0.22 s/mol.
# Processing CHEMBL378677 in molecule.smi (52/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210972 in molecule.smi (53/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210972 in molecule.smi (54/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210145 in molecule.smi (55/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210145 in molecule.smi (56/133). Average speed: 0.21 s/mol.
# Processing CHEMBL377225 in molecule.smi (57/133). Average speed: 0.21 s/mol.
# Processing CHEMBL377225 in molecule.smi (58/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210823 in molecule.smi (59/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210823 in molecule.smi (60/133). Average speed: 0.21 s/mol.
# Processing CHEMBL207381 in molecule.smi (61/133). Average speed: 0.21 s/mol.
# Processing CHEMBL207381 in molecule.smi (62/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210511 in molecule.smi (63/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210511 in molecule.smi (64/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210632 in molecule.smi (65/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210632 in molecule.smi (66/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210497 in molecule.smi (67/133). Average speed: 0.21 s/mol.
# Processing CHEMBL208584 in molecule.smi (69/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210497 in molecule.smi (68/133). Average speed: 0.21 s/mol.
# Processing CHEMBL208584 in molecule.smi (70/133). Average speed: 0.21 s/mol.
# Processing CHEMBL208763 in molecule.smi (71/133). Average speed: 0.21 s/mol.
# Processing CHEMBL208763 in molecule.smi (72/133). Average speed: 0.20 s/mol.
# Processing CHEMBL209227 in molecule.smi (73/133). Average speed: 0.21 s/mol.
# Processing CHEMBL210092 in molecule.smi (75/133). Average speed: 0.20 s/mol.
# Processing CHEMBL209227 in molecule.smi (74/133). Average speed: 0.20 s/mol.
# Processing CHEMBL210092 in molecule.smi (76/133). Average speed: 0.20 s/mol.
# Processing CHEMBL377150 in molecule.smi (77/133). Average speed: 0.20 s/mol.
# Processing CHEMBL377150 in molecule.smi (78/133). Average speed: 0.20 s/mol.
# Processing CHEMBL212454 in molecule.smi (79/133). Average speed: 0.20 s/mol.
# Processing CHEMBL213581 in molecule.smi (80/133). Average speed: 0.20 s/mol.
# Processing CHEMBL380403 in molecule.smi (81/133). Average speed: 0.20 s/mol.
# Processing CHEMBL211969 in molecule.smi (83/133). Average speed: 0.20 s/mol.
# Processing CHEMBL212504 in molecule.smi (82/133). Average speed: 0.20 s/mol.
# Processing CHEMBL384739 in molecule.smi (84/133). Average speed: 0.19 s/mol.
# Processing CHEMBL215732 in molecule.smi (85/133). Average speed: 0.19 s/mol.
# Processing CHEMBL212240 in molecule.smi (86/133). Average speed: 0.19 s/mol.
# Processing CHEMBL377253 in molecule.smi (87/133). Average speed: 0.19 s/mol.
# Processing CHEMBL215397 in molecule.smi (88/133). Average speed: 0.19 s/mol.
# Processing CHEMBL379642 in molecule.smi (90/133). Average speed: 0.19 s/mol.
# Processing CHEMBL378342 in molecule.smi (89/133). Average speed: 0.19 s/mol.
# Processing CHEMBL427404 in molecule.smi (91/133). Average speed: 0.19 s/mol.
# Processing CHEMBL212190 in molecule.smi (92/133). Average speed: 0.19 s/mol.
# Processing CHEMBL378700 in molecule.smi (93/133). Average speed: 0.19 s/mol.
# Processing CHEMBL212019 in molecule.smi (94/133). Average speed: 0.19 s/mol.
# Processing CHEMBL212399 in molecule.smi (95/133). Average speed: 0.18 s/mol.
# Processing CHEMBL215733 in molecule.smi (96/133). Average speed: 0.18 s/mol.
# Processing CHEMBL375130 in molecule.smi (97/133). Average speed: 0.18 s/mol.
# Processing CHEMBL214372 in molecule.smi (98/133). Average speed: 0.18 s/mol.
# Processing CHEMBL212218 in molecule.smi (99/133). Average speed: 0.18 s/mol.
# Processing CHEMBL222840 in molecule.smi (100/133). Average speed: 0.18 s/mol.
# Processing CHEMBL222769 in molecule.smi (101/133). Average speed: 0.18 s/mol.
# Processing CHEMBL222735 in molecule.smi (102/133). Average speed: 0.18 s/mol.
# Processing CHEMBL222628 in molecule.smi (103/133). Average speed: 0.17 s/mol.
# Processing CHEMBL222893 in molecule.smi (104/133). Average speed: 0.17 s/mol.
# Processing CHEMBL225515 in molecule.smi (105/133). Average speed: 0.17 s/mol.
# Processing CHEMBL222234 in molecule.smi (106/133). Average speed: 0.17 s/mol.
# Processing CHEMBL426898 in molecule.smi (107/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187266 in molecule.smi (108/133). Average speed: 0.17 s/mol.
# Processing CHEMBL215254 in molecule.smi (109/133). Average speed: 0.17 s/mol.
# Processing CHEMBL2146517 in molecule.smi (110/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187460 in molecule.smi (111/133). Average speed: 0.17 s/mol.
# Processing CHEMBL363535 in molecule.smi (112/133). Average speed: 0.17 s/mol.
# Processing CHEMBL227075 in molecule.smi (113/133). Average speed: 0.17 s/mol.
# Processing CHEMBL45830 in molecule.smi (114/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187266 in molecule.smi (115/133). Average speed: 0.17 s/mol.
# Processing CHEMBL215254 in molecule.smi (116/133). Average speed: 0.17 s/mol.
# Processing CHEMBL2146517 in molecule.smi (117/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187460 in molecule.smi (118/133). Average speed: 0.17 s/mol.
# Processing CHEMBL363535 in molecule.smi (119/133). Average speed: 0.17 s/mol.
# Processing CHEMBL227075 in molecule.smi (120/133). Average speed: 0.17 s/mol.
# Processing CHEMBL45830 in molecule.smi (121/133). Average speed: 0.17 s/mol.
# Processing CHEMBL215254 in molecule.smi (122/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187460 in molecule.smi (123/133). Average speed: 0.17 s/mol.
# Processing CHEMBL363535 in molecule.smi (124/133). Average speed: 0.17 s/mol.
# Processing CHEMBL227075 in molecule.smi (125/133). Average speed: 0.17 s/mol.
# Processing CHEMBL45830 in molecule.smi (126/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187266 in molecule.smi (127/133). Average speed: 0.17 s/mol.
# Processing CHEMBL215254 in molecule.smi (128/133). Average speed: 0.17 s/mol.
# Processing CHEMBL2146517 in molecule.smi (129/133). Average speed: 0.17 s/mol.
# Processing CHEMBL187460 in molecule.smi (130/133). Average speed: 0.17 s/mol.
# Processing CHEMBL227075 in molecule.smi (132/133). Average speed: 0.17 s/mol.
# Processing CHEMBL363535 in molecule.smi (131/133). Average speed: 0.17 s/mol.
# Processing CHEMBL45830 in molecule.smi (133/133). Average speed: 0.17 s/mol.
# Descriptor calculation completed in 22.788 secs . Average speed: 0.17 s/mol.

# %%
! ls -l
# Out:
# total 25720
# -rw-r--r-- 1 root root    17053 Dec 16 09:44 'covid_04_bioactivity_data_3class_pIC50 (1) (1).csv'
# -rw-r--r-- 1 root root   247688 Dec 16 09:51  descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Dec 16 09:49  __MACOSX
# -rw-r--r-- 1 root root     7991 Dec 16 09:49  molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020  PaDEL-Descriptor
# -rw-r--r-- 1 root root   268084 Dec 16 09:42  PaDEL-Descriptor.jar
# -rw-r--r-- 1 root root      231 Dec 16 09:51  padel.sh
# -rw-r--r-- 1 root root 25768637 Dec 16 09:44  padel.zip
# drwxr-xr-x 1 root root     4096 Dec  3 14:33  sample_data

# %%
df3_X = pd.read_csv('descriptors_output.csv')
